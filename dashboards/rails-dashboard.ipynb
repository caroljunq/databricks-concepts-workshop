# %% [markdown]
# # Rails Dashboard Export
# Each cell below contains the JSON definition for a specific chart from the `rails-dashboard.lvdash.json` file.

# %% [markdown]
# ## Page 1: Rail Stops
# ### Chart: Total Stops (Counter)

# %%
{"clipboardKey":"lakeview-dashboards-lastCopiedWidget-clipboard","name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e216f28d72ac561448b7d3","content":{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e216f28d72ac561448b7d3","displayName":"","queries":[{"queryName":"main_query","query":{"datasetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de183b99e53ac29767eb91","fields":[{"expression":"COUNT(`id_evento`)","fieldName":"count(id_evento)"}],"disaggregatedData":false,"parameterValues":[],"filters":[]}}],"parameterQueries":[],"renderSpec":{"type":1,"vizRenderSpec":{"widgetContent":{"version":2,"frame":{"title":"Total Stops","showTitle":true},"widgetType":"counter","encodings":{"value":{"fieldName":"count(id_evento)","displayName":"Total"}}}}},"etag":"-1769320288","customerRefId":"total_stops","parseWarnings":[],"upgradeStatus":{"warnings":[]},"upgradeFailed":false},"layout":{"widgetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e216f28d72ac561448b7d3","xCoordinate":0,"yCoordinate":0,"width":2,"height":4},"datasets":[{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de183b99e53ac29767eb91","displayName":"paradas","query":"SELECT * FROM workshop_rails.rails.paradas","etag":"-246623751","preferLowCode":false,"parameters":[],"columns":[],"customerRefId":"8b941e00"}]}

# %% [markdown]
# ### Chart: Total Maintenance

# %%
{"clipboardKey":"lakeview-dashboards-lastCopiedWidget-clipboard","name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e21752bcc3cf331d655a92","content":{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e21752bcc3cf331d655a92","displayName":"","queries":[{"queryName":"main_query","query":{"datasetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de1830a35596c1c19d58a8","fields":[{"expression":"SUM(`custo_manutencao_corretiva_brl`)","fieldName":"sum(custo_manutencao_corretiva_brl)"}],"disaggregatedData":false,"parameterValues":[],"filters":[]}}],"parameterQueries":[],"renderSpec":{"type":1,"vizRenderSpec":{"widgetContent":{"version":2,"frame":{"title":"Total Maintenance Cost (BRL)","showTitle":true},"widgetType":"counter","encodings":{"value":{"fieldName":"sum(custo_manutencao_corretiva_brl)","format":{"type":"number-currency","currencyCode":"BRL","decimalPlaces":{"type":"exact","places":0},"abbreviation":"compact"},"displayName":"Total"}}}}},"etag":"1893082478","customerRefId":"total_maintenance_cost","parseWarnings":[],"upgradeStatus":{"warnings":[]},"upgradeFailed":false},"layout":{"widgetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e21752bcc3cf331d655a92","xCoordinate":4,"yCoordinate":0,"width":2,"height":4},"datasets":[{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de1830a35596c1c19d58a8","displayName":"monitoramento_trilhos","query":"SELECT * FROM workshop_rails.rails.monitoramento_trilhos","etag":"206549782","preferLowCode":false,"parameters":[],"columns":[],"customerRefId":"329276dc"}]}

# %% [markdown]
# ### Chart: Stops by Reason (Pie Chart)

# %%
{"clipboardKey":"lakeview-dashboards-lastCopiedWidget-clipboard","name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e217599f3ea5b591e8ed31","content":{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e217599f3ea5b591e8ed31","displayName":"","queries":[{"queryName":"main_query","query":{"datasetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de183b99e53ac29767eb91","fields":[{"expression":"COUNT(`id_evento`)","fieldName":"count(id_evento)"},{"expression":"`motivo_parada`","fieldName":"motivo_parada"}],"disaggregatedData":false,"parameterValues":[],"filters":[]}}],"parameterQueries":[],"renderSpec":{"type":1,"vizRenderSpec":{"widgetContent":{"version":3,"frame":{"title":"Stops by Reason","showTitle":true},"widgetType":"pie","encodings":{"angle":{"fieldName":"count(id_evento)","scale":{"type":"quantitative"},"displayName":"Count"},"color":{"fieldName":"motivo_parada","displayName":"Reason","scale":{"type":"categorical"}},"label":{"show":true}}}}},"etag":"-1552231059","customerRefId":"stops_by_reason","parseWarnings":[],"upgradeStatus":{"warnings":[]},"upgradeFailed":false},"layout":{"widgetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e217599f3ea5b591e8ed31","xCoordinate":0,"yCoordinate":4,"width":3,"height":8},"datasets":[{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de183b99e53ac29767eb91","displayName":"paradas","query":"SELECT * FROM workshop_rails.rails.paradas","etag":"-246623751","preferLowCode":false,"parameters":[],"columns":[],"customerRefId":"8b941e00"}]}

# %% [markdown]
# ### Chart: Stops by State (Bar Chart)

# %%
{"clipboardKey":"lakeview-dashboards-lastCopiedWidget-clipboard","name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e217608a0106910e622fdc","content":{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e217608a0106910e622fdc","displayName":"","queries":[{"queryName":"main_query","query":{"datasetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de184b96d3e36dd8e8d1ce","fields":[{"expression":"`estado`","fieldName":"estado"},{"expression":"COUNT(`id_evento`)","fieldName":"count(id_evento)"}],"disaggregatedData":false,"parameterValues":[],"filters":[]}}],"parameterQueries":[],"renderSpec":{"type":1,"vizRenderSpec":{"widgetContent":{"version":3,"frame":{"title":"Stops by State","showTitle":true},"widgetType":"bar","encodings":{"x":{"fieldName":"estado","displayName":"State","scale":{"type":"categorical","sort":{"by":"y-reversed"}}},"y":{"fieldName":"count(id_evento)","displayName":"Total Stops","scale":{"type":"quantitative"}},"color":{"fieldName":"estado","displayName":"State","scale":{"type":"categorical"}},"label":{"show":true}}}}},"etag":"1373081696","customerRefId":"stops_by_state","parseWarnings":[],"upgradeStatus":{"warnings":[]},"upgradeFailed":false},"layout":{"widgetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e217608a0106910e622fdc","xCoordinate":3,"yCoordinate":4,"width":3,"height":8},"datasets":[{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de184b96d3e36dd8e8d1ce","displayName":"stops_with_geography","query":"SELECT p.*, g.estado, g.cidade_referencia, g.tipo_geometria \nFROM workshop_rails.rails.paradas p \nLEFT JOIN workshop_rails.rails.geografia_linha g ON p.id_secao = g.id_secao","etag":"1310575390","preferLowCode":false,"parameters":[],"columns":[],"customerRefId":"c73fdc20"}]}

# %% [markdown]
# ### Chart: Stops by Track Geometry

# %%
{"clipboardKey":"lakeview-dashboards-lastCopiedWidget-clipboard","name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e217678a4119cf9ca21840","content":{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e217678a4119cf9ca21840","displayName":"","queries":[{"queryName":"main_query","query":{"datasetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de184b96d3e36dd8e8d1ce","fields":[{"expression":"`tipo_geometria`","fieldName":"tipo_geometria"},{"expression":"COUNT(`id_evento`)","fieldName":"count(id_evento)"}],"disaggregatedData":false,"parameterValues":[],"filters":[]}}],"parameterQueries":[],"renderSpec":{"type":1,"vizRenderSpec":{"widgetContent":{"version":3,"frame":{"title":"Stops by Track Geometry","showTitle":true},"widgetType":"bar","encodings":{"x":{"fieldName":"tipo_geometria","displayName":"Geometry","scale":{"type":"categorical","sort":{"by":"y-reversed"}}},"y":{"fieldName":"count(id_evento)","displayName":"Count","scale":{"type":"quantitative"}},"color":{"fieldName":"tipo_geometria","displayName":"Geometry","scale":{"type":"categorical"}},"label":{"show":true}}}}},"etag":"-1790301636","customerRefId":"stops_by_geometry","parseWarnings":[],"upgradeStatus":{"warnings":[]},"upgradeFailed":false},"layout":{"widgetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e217678a4119cf9ca21840","xCoordinate":0,"yCoordinate":12,"width":3,"height":8},"datasets":[{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de184b96d3e36dd8e8d1ce","displayName":"stops_with_geography","query":"SELECT p.*, g.estado, g.cidade_referencia, g.tipo_geometria \nFROM workshop_rails.rails.paradas p \nLEFT JOIN workshop_rails.rails.geografia_linha g ON p.id_secao = g.id_secao","etag":"1310575390","preferLowCode":false,"parameters":[],"columns":[],"customerRefId":"c73fdc20"}]}

# %% [markdown]
# ### Chart: Stops by Track Geometry

# %%
{"clipboardKey":"lakeview-dashboards-lastCopiedWidget-clipboard","name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e217678a4119cf9ca21840","content":{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e217678a4119cf9ca21840","displayName":"","queries":[{"queryName":"main_query","query":{"datasetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de184b96d3e36dd8e8d1ce","fields":[{"expression":"`tipo_geometria`","fieldName":"tipo_geometria"},{"expression":"COUNT(`id_evento`)","fieldName":"count(id_evento)"}],"disaggregatedData":false,"parameterValues":[],"filters":[]}}],"parameterQueries":[],"renderSpec":{"type":1,"vizRenderSpec":{"widgetContent":{"version":3,"frame":{"title":"Stops by Track Geometry","showTitle":true},"widgetType":"bar","encodings":{"x":{"fieldName":"tipo_geometria","displayName":"Geometry","scale":{"type":"categorical","sort":{"by":"y-reversed"}}},"y":{"fieldName":"count(id_evento)","displayName":"Count","scale":{"type":"quantitative"}},"color":{"fieldName":"tipo_geometria","displayName":"Geometry","scale":{"type":"categorical"}},"label":{"show":true}}}}},"etag":"-1790301636","customerRefId":"stops_by_geometry","parseWarnings":[],"upgradeStatus":{"warnings":[]},"upgradeFailed":false},"layout":{"widgetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e217678a4119cf9ca21840","xCoordinate":0,"yCoordinate":12,"width":3,"height":8},"datasets":[{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de184b96d3e36dd8e8d1ce","displayName":"stops_with_geography","query":"SELECT p.*, g.estado, g.cidade_referencia, g.tipo_geometria \nFROM workshop_rails.rails.paradas p \nLEFT JOIN workshop_rails.rails.geografia_linha g ON p.id_secao = g.id_secao","etag":"1310575390","preferLowCode":false,"parameters":[],"columns":[],"customerRefId":"c73fdc20"}]}

# %% [markdown]
# ### Chart: Maintenance Cost by Section

# %%
{"clipboardKey":"lakeview-dashboards-lastCopiedWidget-clipboard","name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e2176e9b49bd7514ad2ea0","content":{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e2176e9b49bd7514ad2ea0","displayName":"","queries":[{"queryName":"main_query","query":{"datasetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de1830a35596c1c19d58a8","fields":[{"expression":"`id_secao`","fieldName":"id_secao"},{"expression":"SUM(`custo_manutencao_corretiva_brl`)","fieldName":"sum(custo_manutencao_corretiva_brl)"}],"disaggregatedData":false,"parameterValues":[],"filters":[]}}],"parameterQueries":[],"renderSpec":{"type":1,"vizRenderSpec":{"widgetContent":{"version":3,"frame":{"title":"Maintenance Cost by Section","showTitle":true},"widgetType":"bar","encodings":{"x":{"fieldName":"id_secao","displayName":"Section","scale":{"type":"categorical","sort":{"by":"y-reversed"}}},"y":{"fieldName":"sum(custo_manutencao_corretiva_brl)","format":{"type":"number-currency","currencyCode":"BRL","decimalPlaces":{"type":"exact","places":0},"abbreviation":"compact"},"displayName":"Cost (BRL)","scale":{"type":"quantitative"}},"color":{"fieldName":"id_secao","displayName":"Section","scale":{"type":"categorical"}}}}}},"etag":"-1775816513","customerRefId":"maintenance_cost_by_section","parseWarnings":[],"upgradeStatus":{"warnings":[]},"upgradeFailed":false},"layout":{"widgetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e0191fafc1e3cccb1d99f5/widgets/01f10609f3e2176e9b49bd7514ad2ea0","xCoordinate":3,"yCoordinate":12,"width":3,"height":8},"datasets":[{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de1830a35596c1c19d58a8","displayName":"monitoramento_trilhos","query":"SELECT * FROM workshop_rails.rails.monitoramento_trilhos","etag":"206549782","preferLowCode":false,"parameters":[],"columns":[],"customerRefId":"329276dc"}]}

# %% [markdown]
# ## Page 2: Track & Telemetry
# ### Chart: Avg Lateral Friction by Geometry

# %%
{"clipboardKey":"lakeview-dashboards-lastCopiedWidget-clipboard","name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e01929a5767ea47092c63c/widgets/01f10609f3e31cee9ea80af55c628054","content":{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e01929a5767ea47092c63c/widgets/01f10609f3e31cee9ea80af55c628054","displayName":"","queries":[{"queryName":"main_query","query":{"datasetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de1830a35596c1c19d58a8","fields":[{"expression":"`tipo_geometria_snapshot`","fieldName":"tipo_geometria_snapshot"},{"expression":"AVG(`atrito_lateral_flange`)","fieldName":"avg(atrito_lateral_flange)"}],"disaggregatedData":false,"parameterValues":[],"filters":[]}}],"parameterQueries":[],"renderSpec":{"type":1,"vizRenderSpec":{"widgetContent":{"version":3,"frame":{"title":"Avg Lateral Friction by Geometry","showTitle":true},"widgetType":"bar","encodings":{"x":{"fieldName":"tipo_geometria_snapshot","displayName":"Geometry","scale":{"type":"categorical","sort":{"by":"y-reversed"}}},"y":{"fieldName":"avg(atrito_lateral_flange)","format":{"type":"number-plain","decimalPlaces":{"type":"exact","places":2},"abbreviation":"none"},"displayName":"Avg Friction","scale":{"type":"quantitative"}},"color":{"fieldName":"tipo_geometria_snapshot","displayName":"Geometry","scale":{"type":"categorical"}},"label":{"show":true}}}}},"etag":"2146085841","customerRefId":"avg_lateral_friction_by_geometry","parseWarnings":[],"upgradeStatus":{"warnings":[]},"upgradeFailed":false},"layout":{"widgetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e01929a5767ea47092c63c/widgets/01f10609f3e31cee9ea80af55c628054","xCoordinate":0,"yCoordinate":14,"width":3,"height":8},"datasets":[{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de1830a35596c1c19d58a8","displayName":"monitoramento_trilhos","query":"SELECT * FROM workshop_rails.rails.monitoramento_trilhos","etag":"206549782","preferLowCode":false,"parameters":[],"columns":[],"customerRefId":"329276dc"}]}

# %% [markdown]
# ### Chart: Maintenance Cost by Geometry Type

# %%
{"clipboardKey":"lakeview-dashboards-lastCopiedWidget-clipboard","name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e01929a5767ea47092c63c/widgets/01f10609f3e31cf5989751dece916d9f","content":{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e01929a5767ea47092c63c/widgets/01f10609f3e31cf5989751dece916d9f","displayName":"","queries":[{"queryName":"main_query","query":{"datasetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de1830a35596c1c19d58a8","fields":[{"expression":"`tipo_geometria_snapshot`","fieldName":"tipo_geometria_snapshot"},{"expression":"SUM(`custo_manutencao_corretiva_brl`)","fieldName":"sum(custo_manutencao_corretiva_brl)"}],"disaggregatedData":false,"parameterValues":[],"filters":[]}}],"parameterQueries":[],"renderSpec":{"type":1,"vizRenderSpec":{"widgetContent":{"version":3,"frame":{"title":"Maintenance Cost by Geometry Type","showTitle":true},"widgetType":"bar","encodings":{"x":{"fieldName":"tipo_geometria_snapshot","displayName":"Geometry","scale":{"type":"categorical","sort":{"by":"y-reversed"}}},"y":{"fieldName":"sum(custo_manutencao_corretiva_brl)","format":{"type":"number-currency","currencyCode":"BRL","decimalPlaces":{"type":"exact","places":0},"abbreviation":"compact"},"displayName":"Total Cost (BRL)","scale":{"type":"quantitative"}},"color":{"fieldName":"tipo_geometria_snapshot","displayName":"Geometry","scale":{"type":"categorical"}},"label":{"show":true}}}}},"etag":"1971411542","customerRefId":"maintenance_cost_by_geometry","parseWarnings":[],"upgradeStatus":{"warnings":[]},"upgradeFailed":false},"layout":{"widgetName":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/pages/01f10609f3e01929a5767ea47092c63c/widgets/01f10609f3e31cf5989751dece916d9f","xCoordinate":3,"yCoordinate":14,"width":3,"height":8},"datasets":[{"name":"dashboards/01f10609f3de115fbbea7e4ab9fd903a/datasets/01f10609f3de1830a35596c1c19d58a8","displayName":"monitoramento_trilhos","query":"SELECT * FROM workshop_rails.rails.monitoramento_trilhos","etag":"206549782","preferLowCode":false,"parameters":[],"columns":[],"customerRefId":"329276dc"}]}
